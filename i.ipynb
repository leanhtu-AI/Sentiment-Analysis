# %%
import pandas as pd
df_train = pd.read_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/ASBA/data/train_clean_V2.csv", index_col = 0)
df_val = pd.read_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/ASBA/data/dev_clean_V2.csv", index_col = 0)
df_test = pd.read_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/ASBA/data/test_clean_V2.csv", index_col = 0)

# %%
df_train = df_train.drop('label_processed',axis=1)
df_test= df_test.drop('label_processed',axis=1)
df_val = df_val.drop('label_processed',axis=1)

# %%
df_train.head(3)
# Out:
#                                                  comment  'CAMERA'  'SCREEN'  \
# index
# 0      Mới mua máy này Tại thegioididong thốt nốt cảm...         3         0
# 1      Pin kém còn lại miễn chê mua 8/3/2019 tình trạ...         0         0
# 2      Sao lúc gọi điện thoại màn hình bị chấm nhỏ nh...         0         0
#
#        'GENERAL'  'STORAGE'  'PERFORMANCE'  'SERACC'  'BATTERY'  'PRICE'  \
# index
# 0              3          0              0         3          3        3
# 1              3          0              0         0          1        0
# 2              0          0              0         0          0        0
#
#        'DESIGN'  'FEATURES'
# index
# 0             0           3
# 1             0           0
# 2             0           1

# %%
df_val.head(2)
# Out:
#                                                  comment  'CAMERA'  'SCREEN'  \
# index
# 0      Điện thoải ổn. Facelock cực nhanh, vân tay ôk ...         0         3
# 1      Mình mới  mua vivo91c. Tải ứng dụng ,games  nh...         0         0
#
#        'GENERAL'  'STORAGE'  'PERFORMANCE'  'SERACC'  'BATTERY'  'PRICE'  \
# index
# 0              3          0              3         0          0        0
# 1              0          0              3         3          0        0
#
#        'DESIGN'  'FEATURES'
# index
# 0             0           3
# 1             0           1

# %%
df_train = df_train.rename(columns=lambda x: x.strip("''"))
df_test = df_test.rename(columns=lambda x: x.strip("''"))
df_val = df_val.rename(columns=lambda x: x.strip("''"))

# %%
df_train.to_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/ASBA/data/Train_clean.csv", index=False)
df_test.to_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/ASBA/data/Test_clean.csv", index=False)
df_val.to_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/ASBA/data/Val_clean.csv", index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/FPTSHOP/OneDrive/Documents/SAV/RawData/mobileData/Train.csv")

# %%
df
# Out:
#                                                 comment  CAMERA  SCREEN  \
# 0     Máy ok, k chê điểm nào, chính thức là fans ViV...       0       0
# 1     Mới sài được 3 ngày sản phẩm thì khá là ok , l...       3       0
# 2     Dùng tốt chơi game bao mượt không nóng như lời...       0       0
# 3     Có ai giống mh kg, mh mua ip 7 plus , mấy bị h...       0       0
# 4     Ko bjk ngày mai có ra đổi đc ko đây. Mới mua h...       0       0
# ...                                                 ...     ...     ...
# 1107  Mua về xài hơn tháng giờ sạc không vào pin. Gử...       0       0
# 1108  Mới mua cái samsung A10s sài chưa đầy 1 tháng ...       0       0
# 1109  máy sử dụng mượt thiết kế rất ok. pin cũng khá...       0       0
# 1110  Máy có mẫu mã đẹp, pin sử dụng được 2 ngày, gi...       0       0
# 1111  Mới mua máy chưa biết sử dụng ra sao nhưng nhâ...       0       0
#
#       GENERAL  STORAGE  PERFORMANCE  SERACC  BATTERY  PRICE  DESIGN  FEATURES
# ...
